# %%
# Importing dataset from Roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="17lXdMhcOELpVUZG10D8")
project = rf.workspace("myplayground-2yoge").project("ppi-emotional-detection")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.91, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to PPI-Emotional-Detection-2 in yolov8:: 100%|██████████| 100/100 [00:00<00:00, 401.32it/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=100, imgsz=640, batch=8
# Out:
# WARNING ⚠️ argument 'epochs=100,' does not require trailing comma ',', updating to 'epochs=100'.
# WARNING ⚠️ argument 'imgsz=640,' does not require trailing comma ',', updating to 'imgsz=640'.
# ...
# Ultralytics YOLOv8.2.91 🚀 Python-3.12.2 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-11300H 3.10GHz)
# ...

# %%
# !yolo task=detect mode=val model=./runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.2.91 🚀 Python-3.12.2 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-11300H 3.10GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                    all          8          8       0.99      0.875      0.982      0.715
# Speed: 3.5ms preprocess, 94.4ms inference, 0.0ms loss, 7.6ms postprocess per image
# Results saved to runs\detect\val
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning C:\Users\conta\Documents\emotion-detection-ppi\notebook\PPI-Emotional-Detection-2\valid\labels.cache... 8 images, 0 backgrounds, 0 corrupt: 100%|██████████| 8/8 [00:00<?, ?it/s]
# val: Scanning C:\Users\conta\Documents\emotion-detection-ppi\notebook\PPI-Emotional-Detection-2\valid\labels.cache... 8 images, 0 backgrounds, 0 corrupt: 100%|██████████| 8/8 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# !yolo task=detect mode=predict model=./runs/detect/train/weights/best.pt source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.2.91 🚀 Python-3.12.2 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-11300H 3.10GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/7 c:\Users\conta\Documents\emotion-detection-ppi\notebook\PPI-Emotional-Detection-2\test\images\sad-11-_jpg.rf.ade2066b3b66dc704575794e7d639d79.jpg: 640x640 1 sad, 117.7ms
# image 2/7 c:\Users\conta\Documents\emotion-detection-ppi\notebook\PPI-Emotional-Detection-2\test\images\sad-18-_jpg.rf.86b2966d032d6e247df167aa9a113000.jpg: 640x640 1 sad, 157.3ms
# image 3/7 c:\Users\conta\Documents\emotion-detection-ppi\notebook\PPI-Emotional-Detection-2\test\images\sad-19-_jpg.rf.ef70b424526438ebefd9db301c1dca93.jpg: 640x640 1 sad, 108.0ms
# image 4/7 c:\Users\conta\Documents\emotion-detection-ppi\notebook\PPI-Emotional-Detection-2\test\images\sad-23-_jpg.rf.aabc6c6f781c90b1d528cab1ab6d8fb0.jpg: 640x640 1 sad, 468.9ms
# ...

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

for file in glob.glob("./runs/detect/predict/*.jpg"):
    img = mpimg.imread(file)
    plt.figure(figsize=(8,6))
    plt.imshow(img)
    plt.show()
